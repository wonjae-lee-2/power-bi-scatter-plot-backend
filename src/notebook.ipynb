# %%
import pandas as pd

# %%
df = pd.read_pickle('data_operation.pickle')

# %%
df
# Out:
#      year1  year2            measure1            measure2     category  \
# 1     2017   2017           Budget_OL           Budget_OL    operation
# 16    2017   2017           Budget_OL           Budget_OL    operation
# 17    2017   2017           Budget_OL           Budget_OL    operation
# 18    2017   2017           Budget_OL           Budget_OL    operation
# 19    2017   2017           Budget_OL           Budget_OL    operation
# ..     ...    ...                 ...                 ...          ...
# 600   2022   2022  Budget_OP_Pillar_3  Budget_OP_Pillar_3    operation
# 601   2022   2022  Budget_OP_Pillar_3  Budget_OP_Pillar_3    operation
# 602   2022   2022  Budget_OP_Pillar_3  Budget_OP_Pillar_3    operation
# 603   2022   2022  Budget_OP_Pillar_3  Budget_OP_Pillar_3    operation
# 0     2022   2022  Budget_OP_Pillar_3  Budget_OP_Pillar_3  correlation
#
#                            region       operation             x             y  \
# ...

# %%
df1 = df[df.category == 'operation']

# %%
df1[df1.z.isna() & (df1.measure1 != df1.measure2)]
# Out:
#      year1  year2                                      measure1  \
# 1     2017   2017  Ratio_Budget_WOL_ABOD_Fix_vs_Budget_WOL_ABOD
# 16    2017   2017  Ratio_Budget_WOL_ABOD_Fix_vs_Budget_WOL_ABOD
# 17    2017   2017  Ratio_Budget_WOL_ABOD_Fix_vs_Budget_WOL_ABOD
# 18    2017   2017  Ratio_Budget_WOL_ABOD_Fix_vs_Budget_WOL_ABOD
# 19    2017   2017  Ratio_Budget_WOL_ABOD_Fix_vs_Budget_WOL_ABOD
# ..     ...    ...                                           ...
# 599   2022   2022  Ratio_Budget_WOL_ABOD_Var_vs_Budget_WOL_ABOD
# 600   2022   2022  Ratio_Budget_WOL_ABOD_Var_vs_Budget_WOL_ABOD
# 601   2022   2022  Ratio_Budget_WOL_ABOD_Var_vs_Budget_WOL_ABOD
# 602   2022   2022  Ratio_Budget_WOL_ABOD_Var_vs_Budget_WOL_ABOD
# 603   2022   2022  Ratio_Budget_WOL_ABOD_Var_vs_Budget_WOL_ABOD
#
#                                          measure2   category  \
# 1    Ratio_Budget_WOL_ABOD_Var_vs_Budget_WOL_ABOD  operation
# 16   Ratio_Budget_WOL_ABOD_Var_vs_Budget_WOL_ABOD  operation
# ...
